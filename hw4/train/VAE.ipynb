# %%
import torch
import numpy as np
import skimage.io
import skimage
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
from torch.autograd import Variable
import torchvision
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import pandas as pd
import pickle
# %matplotlib inline
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
torch.manual_seed(38)

# %%
# load data
train_X = np.load("train_img_2.npy")
test_X = np.load("test_img_2.npy")
train_X = torch.from_numpy(train_X).type(torch.FloatTensor)
test_X = torch.from_numpy(test_X).type(torch.FloatTensor)

train_attr = pd.read_csv("hw4_data/train.csv")
test_attr = pd.read_csv("hw4_data/test.csv")

# %%
# define model
class VAE(nn.Module):
    def __init__(self, latent_size):
        super(VAE, self).__init__()
        # torch.nn.Conv2d(in_channels, out_channels, kernel_size, 
        # stride=1, padding=0, dilation=1, groups=1, bias=True)
        self.latent_size = latent_size
        self.conv_stage = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.01, inplace=True),
            
            nn.Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.01, inplace=True),
            
            nn.Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.01, inplace=True),
            
            nn.Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.01, inplace=True),
        )
        self.fcMean = nn.Linear(4096, self.latent_size)
        self.fcStd = nn.Linear(4096, self.latent_size)
        
        self.fcDecode = nn.Linear(self.latent_size,4096)
        
        self.trans_conv_stage = nn.Sequential(

            nn.ConvTranspose2d(256, 128, 4, 2, padding=1,bias=False),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.01, inplace=True),
 
            nn.ConvTranspose2d(128, 64, 4, 2, padding=1,bias=False),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.01, inplace=True),
 
            nn.ConvTranspose2d(64, 32, 4, 2, padding=1,bias=False),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.01, inplace=True),
            
            nn.ConvTranspose2d(32, 3, 4, 2, padding=1,bias=False)
        )
        # final output activation function
        self.sigmoid = nn.Sigmoid()
        self.tanh = nn.Tanh()
    def encode(self, x):
        conv_output = self.conv_stage(x).view(-1, 4096)
        return self.fcMean(conv_output), self.fcStd(conv_output)

    def reparameterize(self, mu, logvar):
        std = logvar.mul(0.5).exp_()
        eps = torch.FloatTensor(std.size()).normal_()
        eps = Variable(eps).cuda()

        return eps.mul(std).add_(mu)


    def decode(self, z):
        fc_output = self.fcDecode(z).view(-1, 256, 4, 4)
#         print("decode fc output", fc_output.size())
        trans_conv_output = self.trans_conv_stage(fc_output)
#         print("trans_conv_output", trans_conv_output.size())
        return self.tanh(trans_conv_output)

    def forward(self, x):
        mu, logvar = self.encode(x)
#         print("mu shape",mu.size()," logvar",logvar.size())
        z = self.reparameterize(mu, logvar)
#         print("z shape",z.shape)
        return self.decode(z), mu, logvar

def loss_function(recon_x, x, mu, logvar):
#     BCE = F.binary_cross_entropy(recon_x, x, size_average=False)
    
    loss = nn.L1Loss(size_average=False)
#     MSE = F.mse_loss(recon_x, x, size_average=False)
    l1_loss = loss(recon_x, x)
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return l1_loss + KLD, KLD, l1_loss

# %%
# training
latent_size = 100
rand_variable = Variable(torch.randn(32,latent_size),volatile=True).cuda()
model = VAE(latent_size).cuda()
optimizer = optim.Adam(model.parameters(), lr=0.001)
BATCH_SIZE = 64


model.train()

train_MSE = []
train_KLD = []
test_MSE = []
for epoch in range(200):
    print("Epoch:", epoch+1)
    MSE_loss = 0.0
    KLD_loss = 0.0
    total_length = len(train_X)
    # shuffle
    perm_index = torch.randperm(total_length)
    train_X_sfl = train_X[perm_index]
    
    # construct training batch
    for index in range(0,total_length ,BATCH_SIZE):
        if index+BATCH_SIZE > total_length:
            break
            
        # zero the parameter gradients
        optimizer.zero_grad()
        input_X = train_X_sfl[index:index+BATCH_SIZE]

        # use GPU
        input_X = Variable(input_X.cuda())

        # forward + backward + optimize
        recon_batch, mu, logvar = model(input_X)
#         print("recon shape",recon_batch.shape)
#         print("input shape",input_X.shape)
        loss, KLD, MSE = loss_function(recon_batch, input_X, mu, logvar)
        loss.backward()
        optimizer.step()
        MSE_loss += MSE.data[0]
        KLD_loss += KLD.data[0]
    print("training Recon Loss:",MSE_loss/(12288*total_length))
    print("training KLD_loss:", KLD_loss/(total_length))
    train_MSE.append(MSE_loss/(12288*total_length))
    train_KLD.append(KLD_loss/(total_length))
    # evaluation
    model.eval()
    pred = torch.FloatTensor()
    pred = pred.cuda()
    for i in range(len(test_X)):
        input_X_test = Variable(test_X[i].view(1,3,64,64).cuda())
        recon, mu, logvar = model(input_X_test)
        pred = torch.cat((pred,recon.data),0)
    pred = pred.cpu()
    draw_test = torch.cat((test_X[:10],pred[:10]),0) # visual first 10 reconstruct picture
    torchvision.utils.save_image(draw_test/2+0.5, './VAE_output/fig1_3_'+str(epoch+1)+'.jpg',nrow=10)
    
    # calculate test mse
    test_mse = F.mse_loss(Variable(pred), Variable(test_X),size_average=False)/ (64*64*3) / len(pred)
    test_MSE.append(test_mse.data[0])
    print("test MSE",test_mse.data[0])
    print("\n")
    # random generate
    rand_output = model.decode(rand_variable)
    torchvision.utils.save_image(rand_output.cpu().data/2+0.5, './VAE_output/fig1_4_'+str(epoch+1)+'.jpg',nrow=8)
    model.train()
# torch.save(model.state_dict(), "./models/VAE1_model.pkt")
# Out:
# Epoch: 1
# training Recon Loss: 0.16712582596143086
# training KLD_loss: 138.00826738204955
# test MSE 0.03379185125231743
#
#
# Epoch: 2
# training Recon Loss: 0.12586651797294618
# training KLD_loss: 165.26917670898436
# test MSE 0.026494337245821953
#
#
# Epoch: 3
# training Recon Loss: 0.11600189054807027
# training KLD_loss: 173.31403420410157
# test MSE 0.023959722369909286
#
#
# Epoch: 4
# training Recon Loss: 0.11136894952456157
# training KLD_loss: 178.20508132324218
# test MSE 0.02222047746181488
#
#
# Epoch: 5
# training Recon Loss: 0.10682566765149434
# training KLD_loss: 181.64163896484374
# test MSE 0.02216758020222187
#
#
# Epoch: 6
# training Recon Loss: 0.10458458112080891
# training KLD_loss: 182.8094548828125
# test MSE 0.02085774764418602
#
#
# Epoch: 7
# training Recon Loss: 0.10243188455899556
# training KLD_loss: 183.65255808105468
# test MSE 0.020227478817105293
#
#
# Epoch: 8
# training Recon Loss: 0.10152474034627279
# training KLD_loss: 183.65619765625
# test MSE 0.0209827683866024
#
#
# Epoch: 9
# training Recon Loss: 0.10064942049980163
# training KLD_loss: 183.6318864746094
# test MSE 0.019997291266918182
#
#
# Epoch: 10
# training Recon Loss: 0.09982588335673015
# training KLD_loss: 183.67515114746095
# test MSE 0.01984957791864872
#
#
# Epoch: 11
# training Recon Loss: 0.09915217598279318
# training KLD_loss: 183.57175888671875
# test MSE 0.019194189459085464
#
#
# Epoch: 12
# training Recon Loss: 0.09901724820137024
# training KLD_loss: 183.24730773925782
# test MSE 0.019295353442430496
#
#
# Epoch: 13
# training Recon Loss: 0.09818693464597067
# training KLD_loss: 183.64074240722655
# test MSE 0.01918826624751091
#
#
# Epoch: 14
# training Recon Loss: 0.09737206846872966
# training KLD_loss: 183.56976069335937
# test MSE 0.01889631152153015
#
#
# Epoch: 15
# training Recon Loss: 0.09731146143277486
# training KLD_loss: 183.2402266845703
# test MSE 0.019133474677801132
#
#
# Epoch: 16
# training Recon Loss: 0.0969341825167338
# training KLD_loss: 183.26726279296875
# test MSE 0.01913401111960411
#
#
# Epoch: 17
# training Recon Loss: 0.0962805623849233
# training KLD_loss: 183.5746400390625
# test MSE 0.019485438242554665
#
#
# Epoch: 18
# training Recon Loss: 0.09600189119974772
# training KLD_loss: 183.236754296875
# test MSE 0.018818216398358345
#
#
# Epoch: 19
# training Recon Loss: 0.09558468669255575
# training KLD_loss: 183.504928515625
# test MSE 0.019340816885232925
#
#
# Epoch: 20
# training Recon Loss: 0.09547521236737569
# training KLD_loss: 183.4439675048828
# test MSE 0.01867329515516758
#
#
# Epoch: 21
# training Recon Loss: 0.09471899984677633
# training KLD_loss: 183.57405695800782
# test MSE 0.018576042726635933
#
#
# Epoch: 22
# training Recon Loss: 0.09480056773821513
# training KLD_loss: 183.4757671875
# test MSE 0.018737921491265297
#
#
# Epoch: 23
# training Recon Loss: 0.09473680562973022
# training KLD_loss: 183.53994848632811
# test MSE 0.0185951329767704
#
#
# Epoch: 24
# training Recon Loss: 0.09396508215268452
# training KLD_loss: 183.73676655273437
# test MSE 0.018525388091802597
#
#
# Epoch: 25
# training Recon Loss: 0.09403330771128336
# training KLD_loss: 183.52957124023436
# test MSE 0.018617117777466774
#
#
# Epoch: 26
# training Recon Loss: 0.09377482501665751
# training KLD_loss: 183.64581643066407
# test MSE 0.018585938960313797
#
#
# Epoch: 27
# training Recon Loss: 0.09387587164243062
# training KLD_loss: 183.416889453125
# test MSE 0.018425997346639633
#
#
# Epoch: 28
# training Recon Loss: 0.09360586957931519
# training KLD_loss: 183.5625262451172
# test MSE 0.018364276736974716
#
#
# Epoch: 29
# training Recon Loss: 0.09338886496225993
# training KLD_loss: 183.5283610595703
# test MSE 0.018396424129605293
#
#
# Epoch: 30
# training Recon Loss: 0.09299063878059387
# training KLD_loss: 183.78615283203126
# test MSE 0.018216731026768684
#
#
# Epoch: 31
# training Recon Loss: 0.09291413908004761
# training KLD_loss: 183.68229738769531
# test MSE 0.018402885645627975
#
#
# Epoch: 32
# training Recon Loss: 0.09267743965784708
# training KLD_loss: 183.67548439941407
# test MSE 0.018489880487322807
#
#
# Epoch: 33
# training Recon Loss: 0.09242928463617961
# training KLD_loss: 183.73406357421874
# test MSE 0.018215877935290337
#
#
# Epoch: 34
# training Recon Loss: 0.09244283564885457
# training KLD_loss: 183.74708986816407
# test MSE 0.01822475716471672
#
#
# Epoch: 35
# training Recon Loss: 0.09219966862996419
# training KLD_loss: 183.89794331054688
# test MSE 0.0182917769998312
#
#
# Epoch: 36
# training Recon Loss: 0.09208339794476827
# training KLD_loss: 183.86322692871093
# test MSE 0.018111705780029297
#
#
# Epoch: 37
# training Recon Loss: 0.09217871425946554
# training KLD_loss: 183.79650856933594
# test MSE 0.01845361664891243
#
#
# Epoch: 38
# training Recon Loss: 0.09168008193969726
# training KLD_loss: 183.91576130371095
# test MSE 0.018245115876197815
#
#
# Epoch: 39
# training Recon Loss: 0.09193211516539256
# training KLD_loss: 183.6620133544922
# test MSE 0.018156101927161217
#
#
# Epoch: 40
# training Recon Loss: 0.09156363401412963
# training KLD_loss: 183.9903274169922
# test MSE 0.01810641959309578
#
#
# Epoch: 41
# training Recon Loss: 0.09151267838478089
# training KLD_loss: 183.91625356445311
# test MSE 0.01822451874613762
#
#
# Epoch: 42
# training Recon Loss: 0.09152974039713542
# training KLD_loss: 183.93278601074218
# test MSE 0.018034666776657104
#
#
# Epoch: 43
# training Recon Loss: 0.09135411326090495
# training KLD_loss: 183.99036696777344
# test MSE 0.01813350059092045
#
#
# Epoch: 44
# training Recon Loss: 0.09122147105534871
# training KLD_loss: 183.9585405517578
# test MSE 0.018233198672533035
#
#
# Epoch: 45
# training Recon Loss: 0.09100369556744893
# training KLD_loss: 184.05396398925782
# test MSE 0.018040917813777924
#
#
# Epoch: 46
# training Recon Loss: 0.09104138224919638
# training KLD_loss: 184.10267756347656
# test MSE 0.017954884096980095
#
#
# Epoch: 47
# training Recon Loss: 0.0908257209777832
# training KLD_loss: 184.16562829589844
# test MSE 0.01807967945933342
#
#
# Epoch: 48
# training Recon Loss: 0.09095807101726532
# training KLD_loss: 184.0726893798828
# test MSE 0.018244614824652672
#
#
# Epoch: 49
# training Recon Loss: 0.0905294724146525
# training KLD_loss: 184.27716196289063
# test MSE 0.017907794564962387
#
#
# Epoch: 50
# training Recon Loss: 0.09057501910527548
# training KLD_loss: 184.1794889892578
# test MSE 0.018001550808548927
#
#
# Epoch: 51
# training Recon Loss: 0.0904300128142039
# training KLD_loss: 184.29364904785157
# test MSE 0.017890211194753647
#
#
# Epoch: 52
# training Recon Loss: 0.09035152043501536
# training KLD_loss: 184.25917507324218
# test MSE 0.017945870757102966
#
#
# Epoch: 53
# training Recon Loss: 0.09020571554501851
# training KLD_loss: 184.42384672851563
# test MSE 0.018028855323791504
#
#
# Epoch: 54
# training Recon Loss: 0.09032216838200888
# training KLD_loss: 184.26395830078124
# test MSE 0.018000323325395584
#
#
# Epoch: 55
# training Recon Loss: 0.09018051795959472
# training KLD_loss: 184.3803841796875
# test MSE 0.017861638218164444
#
#
# Epoch: 56
# training Recon Loss: 0.08990252027511597
# training KLD_loss: 184.49472502441407
# test MSE 0.01798941008746624
#
#
# Epoch: 57
# training Recon Loss: 0.08984742426872254
# training KLD_loss: 184.61420236816406
# test MSE 0.01793418824672699
#
#
# Epoch: 58
# training Recon Loss: 0.0899943545182546
# training KLD_loss: 184.25826315917968
# test MSE 0.017810948193073273
#
#
# Epoch: 59
# training Recon Loss: 0.08973943378130594
# training KLD_loss: 184.60540834960938
# test MSE 0.01784772053360939
#
#
# Epoch: 60
# training Recon Loss: 0.08961233795483907
# training KLD_loss: 184.53190078125
# test MSE 0.017734304070472717
#
#
# Epoch: 61
# training Recon Loss: 0.08966391325791677
# training KLD_loss: 184.42129287109375
# test MSE 0.017790554091334343
#
#
# Epoch: 62
# training Recon Loss: 0.08964998274644216
# training KLD_loss: 184.47038845214843
# test MSE 0.018002016469836235
#
#
# Epoch: 63
# training Recon Loss: 0.08960092015266419
# training KLD_loss: 184.54423088378906
# test MSE 0.01774047128856182
#
#
# Epoch: 64
# training Recon Loss: 0.08945265279610952
# training KLD_loss: 184.6254412841797
# test MSE 0.017859507352113724
#
#
# Epoch: 65
# training Recon Loss: 0.08930490941206615
# training KLD_loss: 184.78166447753907
# test MSE 0.017782757058739662
#
#
# Epoch: 66
# training Recon Loss: 0.08924819359779358
# training KLD_loss: 184.75583549804688
# test MSE 0.017647188156843185
#
#
# Epoch: 67
# training Recon Loss: 0.08926919562021891
# training KLD_loss: 184.62660568847656
# test MSE 0.01770724356174469
#
#
# Epoch: 68
# training Recon Loss: 0.08930522275765737
# training KLD_loss: 184.70022744140624
# test MSE 0.017881549894809723
#
#
# Epoch: 69
# training Recon Loss: 0.08901343483130138
# training KLD_loss: 184.84429404296876
# test MSE 0.017842572182416916
#
#
# Epoch: 70
# training Recon Loss: 0.08921340200106304
# training KLD_loss: 184.66486955566407
# test MSE 0.017674041911959648
#
#
# Epoch: 71
# training Recon Loss: 0.08894749978383382
# training KLD_loss: 184.8282748779297
# test MSE 0.017911095172166824
#
#
# Epoch: 72
# training Recon Loss: 0.08900991048018138
# training KLD_loss: 184.74585048828126
# test MSE 0.017773114144802094
#
#
# Epoch: 73
# training Recon Loss: 0.08889111455281576
# training KLD_loss: 184.84820434570312
# test MSE 0.01780891790986061
#
#
# Epoch: 74
# training Recon Loss: 0.08893190550804138
# training KLD_loss: 184.78242463378905
# test MSE 0.0177873857319355
#
#
# Epoch: 75
# training Recon Loss: 0.0888725894610087
# training KLD_loss: 184.86802055664063
# test MSE 0.017848776653409004
#
#
# Epoch: 76
# training Recon Loss: 0.08891156098047892
# training KLD_loss: 184.92460629882814
# test MSE 0.017797356471419334
#
#
# Epoch: 77
# training Recon Loss: 0.08868796022733053
# training KLD_loss: 184.87582150878907
# test MSE 0.01766686514019966
#
#
# Epoch: 78
# training Recon Loss: 0.0886547517935435
# training KLD_loss: 184.96904426269532
# test MSE 0.0177676510065794
#
#
# Epoch: 79
# training Recon Loss: 0.08860840601921081
# training KLD_loss: 185.0259556640625
# test MSE 0.017805838957428932
#
#
# Epoch: 80
# training Recon Loss: 0.08851623644828796
# training KLD_loss: 184.99247751464844
# test MSE 0.017638010904192924
#
#
# Epoch: 81
# training Recon Loss: 0.08850812141895294
# training KLD_loss: 184.837778125
# test MSE 0.017872538417577744
#
#
# Epoch: 82
# training Recon Loss: 0.08852516681353251
# training KLD_loss: 185.16326818847656
# test MSE 0.017673309892416
#
#
# Epoch: 83
# training Recon Loss: 0.08847738631566365
# training KLD_loss: 185.0987435546875
# test MSE 0.017605919390916824
#
#
# Epoch: 84
# training Recon Loss: 0.0883992475827535
# training KLD_loss: 185.04650056152343
# test MSE 0.017702965065836906
#
#
# Epoch: 85
# training Recon Loss: 0.08828373594284057
# training KLD_loss: 185.0857091796875
# test MSE 0.017689945176243782
#
#
# Epoch: 86
# training Recon Loss: 0.08834987171490988
# training KLD_loss: 184.9872381591797
# test MSE 0.017853667959570885
#
#
# Epoch: 87
# training Recon Loss: 0.08827325256665548
# training KLD_loss: 185.13142846679688
# test MSE 0.01764969527721405
#
#
# Epoch: 88
# training Recon Loss: 0.08822672656377156
# training KLD_loss: 185.20521171875
# test MSE 0.017801035195589066
#
#
# Epoch: 89
# training Recon Loss: 0.08804693378607432
# training KLD_loss: 185.20755629882814
# test MSE 0.01768668368458748
#
#
# Epoch: 90
# training Recon Loss: 0.08807161045074463
# training KLD_loss: 185.1825126220703
# test MSE 0.01780899614095688
#
#
# Epoch: 91
# training Recon Loss: 0.08802656764189402
# training KLD_loss: 185.19298393554686
# test MSE 0.017626283690333366
#
#
# Epoch: 92
# training Recon Loss: 0.08793739298979442
# training KLD_loss: 185.34563383789063
# test MSE 0.01776517555117607
#
#
# Epoch: 93
# training Recon Loss: 0.08811207786401112
# training KLD_loss: 185.21276821289064
# test MSE 0.017681293189525604
#
#
# Epoch: 94
# training Recon Loss: 0.08791177221139272
# training KLD_loss: 185.31077280273436
# test MSE 0.01759190671145916
#
#
# Epoch: 95
# training Recon Loss: 0.0880885347366333
# training KLD_loss: 185.10778742675782
# test MSE 0.017769554629921913
#
#
# Epoch: 96
# training Recon Loss: 0.0879178858200709
# training KLD_loss: 185.4779854248047
# test MSE 0.017603719606995583
#
#
# Epoch: 97
# training Recon Loss: 0.08786551801363628
# training KLD_loss: 185.3663088623047
# test MSE 0.017744354903697968
#
#
# Epoch: 98
# training Recon Loss: 0.08778527591228485
# training KLD_loss: 185.27651943359376
# test MSE 0.017611822113394737
#
#
# Epoch: 99
# training Recon Loss: 0.0879591817220052
# training KLD_loss: 185.3145724609375
# test MSE 0.017613941803574562
#
#
# Epoch: 100
# training Recon Loss: 0.08769784800211589
# training KLD_loss: 185.62253005371093
# test MSE 0.01759355701506138
#
#
# Epoch: 101
# training Recon Loss: 0.08779952425161998
# training KLD_loss: 185.4225275390625
# test MSE 0.017540134489536285
#
#
# Epoch: 102
# training Recon Loss: 0.08772337899208069
# training KLD_loss: 185.46226237792968
# test MSE 0.017678262665867805
#
#
# Epoch: 103
# training Recon Loss: 0.08767914026578268
# training KLD_loss: 185.45128295898436
# test MSE 0.01756199449300766
#
#
# Epoch: 104
# training Recon Loss: 0.08777882912158966
# training KLD_loss: 185.3800951171875
# test MSE 0.01770171895623207
#
#
# Epoch: 105
# training Recon Loss: 0.08763180241584778
# training KLD_loss: 185.44685234375
# test MSE 0.017701201140880585
#
#
# Epoch: 106
# training Recon Loss: 0.0876330147266388
# training KLD_loss: 185.45067067871094
# test MSE 0.01773424632847309
#
#
# Epoch: 107
# training Recon Loss: 0.08751582112312317
# training KLD_loss: 185.56292998046874
# test MSE 0.017661795020103455
#
#
# Epoch: 108
# training Recon Loss: 0.08749138436317444
# training KLD_loss: 185.569172265625
# test MSE 0.017711052671074867
#
#
# Epoch: 109
# training Recon Loss: 0.08759490994612376
# training KLD_loss: 185.44636108398439
# test MSE 0.017719438299536705
#
#
# Epoch: 110
# training Recon Loss: 0.08755099116166433
# training KLD_loss: 185.51419287109374
# test MSE 0.017604615539312363
#
#
# Epoch: 111
# training Recon Loss: 0.08753929909865062
# training KLD_loss: 185.6462094482422
# test MSE 0.017664385959506035
#
#
# Epoch: 112
# training Recon Loss: 0.08743553849856059
# training KLD_loss: 185.65080241699218
# test MSE 0.017597051337361336
#
#
# Epoch: 113
# training Recon Loss: 0.08752548028628031
# training KLD_loss: 185.52678759765624
# test MSE 0.017645489424467087
#
#
# Epoch: 114
# training Recon Loss: 0.08727041629155477
# training KLD_loss: 185.72412456054687
# test MSE 0.017673876136541367
#
#
# Epoch: 115
# training Recon Loss: 0.08721877491474152
# training KLD_loss: 185.8178330078125
# test MSE 0.017527615651488304
#
#
# Epoch: 116
# training Recon Loss: 0.08727472269535065
# training KLD_loss: 185.7334956542969
# test MSE 0.017613569274544716
#
#
# Epoch: 117
# training Recon Loss: 0.0873446618159612
# training KLD_loss: 185.70691037597658
# test MSE 0.01750190183520317
#
#
# Epoch: 118
# training Recon Loss: 0.08716606243451436
# training KLD_loss: 185.89646437988281
# test MSE 0.017579538747668266
#
#
# Epoch: 119
# training Recon Loss: 0.08715633767445882
# training KLD_loss: 185.86454599609374
# test MSE 0.017649825662374496
#
#
# Epoch: 120
# training Recon Loss: 0.08728360348542531
# training KLD_loss: 185.72831611328124
# test MSE 0.017601948231458664
#
#
# Epoch: 121
# training Recon Loss: 0.0871952653090159
# training KLD_loss: 185.83332590332031
# test MSE 0.017632365226745605
#
#
# Epoch: 122
# training Recon Loss: 0.08700919466018676
# training KLD_loss: 185.87955783691407
# test MSE 0.017565526068210602
#
#
# Epoch: 123
# training Recon Loss: 0.08723358329137167
# training KLD_loss: 185.73352309570313
# test MSE 0.017679287120699883
#
#
# Epoch: 124
# training Recon Loss: 0.08706925286451976
# training KLD_loss: 185.9657876220703
# test MSE 0.017628444358706474
#
#
# Epoch: 125
# training Recon Loss: 0.08707124631404876
# training KLD_loss: 185.82717504882814
# test MSE 0.01748381368815899
#
#
# Epoch: 126
# training Recon Loss: 0.08688738068739574
# training KLD_loss: 186.03982612304688
# test MSE 0.017548782750964165
#
#
# Epoch: 127
# training Recon Loss: 0.08705840528011322
# training KLD_loss: 185.8321590576172
# test MSE 0.01756395399570465
#
#
# Epoch: 128
# training Recon Loss: 0.08692804711659749
# training KLD_loss: 186.0184110107422
# test MSE 0.01753261499106884
#
#
# Epoch: 129
# training Recon Loss: 0.08698492949008942
# training KLD_loss: 185.9935371826172
# test MSE 0.017600106075406075
#
#
# Epoch: 130
# training Recon Loss: 0.08698022859891255
# training KLD_loss: 185.94638725585938
# test MSE 0.01758449338376522
#
#
# Epoch: 131
# training Recon Loss: 0.08690380761623383
# training KLD_loss: 185.89269201660156
# test MSE 0.0175704937428236
#
#
# Epoch: 132
# training Recon Loss: 0.08681609999338785
# training KLD_loss: 186.02914860839843
# test MSE 0.01756167784333229
#
#
# Epoch: 133
# training Recon Loss: 0.08681830463409423
# training KLD_loss: 186.16758940429688
# test MSE 0.017597908154129982
#
#
# Epoch: 134
# training Recon Loss: 0.08691335896650951
# training KLD_loss: 186.12490993652344
# test MSE 0.017696663737297058
#
#
# Epoch: 135
# training Recon Loss: 0.08677104516824087
# training KLD_loss: 186.0478476074219
# test MSE 0.017662925645709038
#
#
# Epoch: 136
# training Recon Loss: 0.08675665469964346
# training KLD_loss: 186.0927979248047
# test MSE 0.0175869632512331
#
#
# Epoch: 137
# training Recon Loss: 0.086832848238945
# training KLD_loss: 186.1051943359375
# test MSE 0.017518898472189903
#
#
# Epoch: 138
# training Recon Loss: 0.08678295706907908
# training KLD_loss: 186.15199091796876
# test MSE 0.01760585978627205
#
#
# Epoch: 139
# training Recon Loss: 0.08668753674030304
# training KLD_loss: 186.20997509765624
# test MSE 0.017537714913487434
#
#
# Epoch: 140
# training Recon Loss: 0.08677767747243245
# training KLD_loss: 186.1594089111328
# test MSE 0.01764453575015068
#
#
# Epoch: 141
# training Recon Loss: 0.08661199273268382
# training KLD_loss: 186.12277036132812
# test MSE 0.017619384452700615
#
#
# Epoch: 142
# training Recon Loss: 0.08659997029304504
# training KLD_loss: 186.18979780273438
# test MSE 0.017618296667933464
#
#
# Epoch: 143
# training Recon Loss: 0.0866318444331487
# training KLD_loss: 186.18435502929688
# test MSE 0.017619801685214043
#
#
# Epoch: 144
# training Recon Loss: 0.08652615399360657
# training KLD_loss: 186.21538764648437
# test MSE 0.01760384626686573
#
#
# Epoch: 145
# training Recon Loss: 0.0864892557144165
# training KLD_loss: 186.27674807128906
# test MSE 0.01756776124238968
#
#
# Epoch: 146
# training Recon Loss: 0.08658725916544596
# training KLD_loss: 186.39074770507813
# test MSE 0.01752786710858345
#
#
# Epoch: 147
# training Recon Loss: 0.08657011907100677
# training KLD_loss: 186.1827333251953
# test MSE 0.017591705545783043
#
#
# Epoch: 148
# training Recon Loss: 0.08649440813064575
# training KLD_loss: 186.29938706054688
# test MSE 0.017550956457853317
#
#
# Epoch: 149
# training Recon Loss: 0.08653364861011505
# training KLD_loss: 186.18024692382812
# test MSE 0.017607377842068672
#
#
# Epoch: 150
# training Recon Loss: 0.0865011138677597
# training KLD_loss: 186.21150302734375
# test MSE 0.017535852268338203
#
#
# Epoch: 151
# training Recon Loss: 0.08654352885087331
# training KLD_loss: 186.1964984375
# test MSE 0.01752948947250843
#
#
# Epoch: 152
# training Recon Loss: 0.08635528039137523
# training KLD_loss: 186.46512614746095
# test MSE 0.017807895317673683
#
#
# Epoch: 153
# training Recon Loss: 0.08643989137808482
# training KLD_loss: 186.34896127929687
# test MSE 0.017781319096684456
#
#
# Epoch: 154
# training Recon Loss: 0.08643165129025777
# training KLD_loss: 186.3457919433594
# test MSE 0.01750832609832287
#
#
# Epoch: 155
# training Recon Loss: 0.08632838482062022
# training KLD_loss: 186.50054350585938
# test MSE 0.01760750822722912
#
#
# Epoch: 156
# training Recon Loss: 0.08627971487840017
# training KLD_loss: 186.46176408691406
# test MSE 0.017600642517209053
#
#
# Epoch: 157
# training Recon Loss: 0.08624999787012735
# training KLD_loss: 186.53764975585938
# test MSE 0.017582807689905167
#
#
# Epoch: 158
# training Recon Loss: 0.08630625263849895
# training KLD_loss: 186.4044780029297
# test MSE 0.01762545481324196
#
#
# Epoch: 159
# training Recon Loss: 0.08632075043519338
# training KLD_loss: 186.43684875488282
# test MSE 0.017656486481428146
#
#
# Epoch: 160
# training Recon Loss: 0.08622727784315745
# training KLD_loss: 186.45129052734376
# test MSE 0.017542414367198944
#
#
# Epoch: 161
# training Recon Loss: 0.08630146602789561
# training KLD_loss: 186.62349450683593
# test MSE 0.017503518611192703
#
#
# Epoch: 162
# training Recon Loss: 0.0862240292787552
# training KLD_loss: 186.50228449707032
# test MSE 0.017557702958583832
#
#
# Epoch: 163
# training Recon Loss: 0.08625810049374898
# training KLD_loss: 186.52171206054686
# test MSE 0.017492113634943962
#
#
# Epoch: 164
# training Recon Loss: 0.0861908509016037
# training KLD_loss: 186.54390725097656
# test MSE 0.01758110150694847
#
#
# Epoch: 165
# training Recon Loss: 0.08631344475746154
# training KLD_loss: 186.421242578125
# test MSE 0.017528487369418144
#
#
# Epoch: 166
# training Recon Loss: 0.0862537145694097
# training KLD_loss: 186.6086009033203
# test MSE 0.01748627983033657
#
#
# Epoch: 167
# training Recon Loss: 0.08619672170480093
# training KLD_loss: 186.58597338867187
# test MSE 0.017623504623770714
#
#
# Epoch: 168
# training Recon Loss: 0.08623191025257111
# training KLD_loss: 186.56243505859376
# test MSE 0.017553815618157387
#
#
# Epoch: 169
# training Recon Loss: 0.08605906805197398
# training KLD_loss: 186.7419203613281
# test MSE 0.01763315126299858
#
#
# Epoch: 170
# training Recon Loss: 0.08604318296909333
# training KLD_loss: 186.6012192626953
# test MSE 0.01759793609380722
#
#
# Epoch: 171
# training Recon Loss: 0.0862691658894221
# training KLD_loss: 186.41935634765625
# test MSE 0.01765824854373932
#
#
# Epoch: 172
# training Recon Loss: 0.08608071455160776
# training KLD_loss: 186.51605266113282
# test MSE 0.017578255385160446
#
#
# Epoch: 173
# training Recon Loss: 0.08618458422025045
# training KLD_loss: 186.5472998046875
# test MSE 0.017501462250947952
#
#
# Epoch: 174
# training Recon Loss: 0.0860196510473887
# training KLD_loss: 186.57868579101563
# test MSE 0.01751341111958027
#
#
# Epoch: 175
# training Recon Loss: 0.08612474667231242
# training KLD_loss: 186.5975630126953
# test MSE 0.01763230934739113
#
#
# Epoch: 176
# training Recon Loss: 0.08601193343003591
# training KLD_loss: 186.69297014160156
# test MSE 0.017750699073076248
#
#
# Epoch: 177
# training Recon Loss: 0.08601495566368103
# training KLD_loss: 186.6204017089844
# test MSE 0.01759226620197296
#
#
# Epoch: 178
# training Recon Loss: 0.08594339977900187
# training KLD_loss: 186.68947377929686
# test MSE 0.01754908822476864
#
#
# Epoch: 179
# training Recon Loss: 0.08598450144131978
# training KLD_loss: 186.74401955566407
# test MSE 0.01786370575428009
#
#
# Epoch: 180
# training Recon Loss: 0.08596039339701335
# training KLD_loss: 186.73495788574218
# test MSE 0.01763678900897503
#
#
# Epoch: 181
# training Recon Loss: 0.08597170442740122
# training KLD_loss: 186.72312546386718
# test MSE 0.017702266573905945
#
#
# Epoch: 182
# training Recon Loss: 0.08596010986963908
# training KLD_loss: 186.88578994140624
# test MSE 0.017495909705758095
#
#
# Epoch: 183
# training Recon Loss: 0.08591954236030579
# training KLD_loss: 186.88893774414063
# test MSE 0.0175013467669487
#
#
# Epoch: 184
# training Recon Loss: 0.0859057912906011
# training KLD_loss: 186.7554451171875
# test MSE 0.017496077343821526
#
#
# Epoch: 185
# training Recon Loss: 0.08588401404221853
# training KLD_loss: 186.7504809326172
# test MSE 0.017570994794368744
#
#
# Epoch: 186
# training Recon Loss: 0.08592237711747487
# training KLD_loss: 186.7751701660156
# test MSE 0.017685851082205772
#
#
# Epoch: 187
# training Recon Loss: 0.08579098517100016
# training KLD_loss: 187.01710004882813
# test MSE 0.017552928999066353
#
#
# Epoch: 188
# training Recon Loss: 0.08581764484246572
# training KLD_loss: 186.86268530273438
# test MSE 0.017575813457369804
#
#
# Epoch: 189
# training Recon Loss: 0.08578741349379222
# training KLD_loss: 186.9237087158203
# test MSE 0.01761993020772934
#
#
# Epoch: 190
# training Recon Loss: 0.08577207241853078
# training KLD_loss: 186.89540729980467
# test MSE 0.017522120848298073
#
#
# Epoch: 191
# training Recon Loss: 0.08586047115325927
# training KLD_loss: 186.77855861816406
# test MSE 0.01746797375380993
#
#
# Epoch: 192
# training Recon Loss: 0.08592015744050344
# training KLD_loss: 186.7945703857422
# test MSE 0.01755658909678459
#
#
# Epoch: 193
# training Recon Loss: 0.0858039824962616
# training KLD_loss: 186.82120979003906
# test MSE 0.017607342451810837
#
#
# Epoch: 194
# training Recon Loss: 0.08580201336542766
# training KLD_loss: 186.92754279785157
# test MSE 0.01746283657848835
#
#
# Epoch: 195
# training Recon Loss: 0.0857421855767568
# training KLD_loss: 186.91971013183593
# test MSE 0.01761176995933056
#
#
# Epoch: 196
# training Recon Loss: 0.08575114781061809
# training KLD_loss: 186.91444545898437
# test MSE 0.017671579495072365
#
#
# Epoch: 197
# training Recon Loss: 0.08582431263128916
# training KLD_loss: 186.96753381347656
# test MSE 0.017668118700385094
#
#
# Epoch: 198
# training Recon Loss: 0.08567330271402995
# training KLD_loss: 186.87673024902344
# test MSE 0.017554335296154022
#
#
# Epoch: 199
# training Recon Loss: 0.0856757315158844
# training KLD_loss: 186.88110551757813
# test MSE 0.017492562532424927
#
#
# Epoch: 200
# training Recon Loss: 0.08576556821664175
# training KLD_loss: 186.911526171875
# test MSE 0.017643650993704796

# %% [markdown]
# 只改 ouput tanh 跟 input

# %%
# store training log
with open("VAE_trainKLD.pkl", "wb") as f:
    pickle.dump(train_KLD, f)
with open("VAE_trainMSE.pkl", "wb") as f:
    pickle.dump(train_MSE, f)
    
# plot loss
plt.figure(figsize=(16,4))
plt.subplot(1,2,1)
plt.plot(train_KLD)
plt.title("training KL divergence")
plt.xlabel("epoch")

plt.subplot(1,2,2)
plt.plot(train_MSE)
plt.title("training MSE")
plt.xlabel("epoch")
plt.savefig("./VAE_output/fig1_2.jpg")
plt.show()

# %%
# visialize the latent space
input_X_test = Variable(test_X).cuda()
mu, logvar = model.encode(input_X_test)
#         print("mu shape",mu.size()," logvar",logvar.size())
latent_space = mu.cpu().data.numpy()

# %%
latent_embedded = TSNE(n_components=2, perplexity=30.0, random_state=38).fit_transform(latent_space)

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(15,5))
attr_arr = np.array(test_attr["Male"])
for i in [0,1]:
    if i==1:
        color="cornflowerblue"
        gender = "Male"
    else:
        color="hotpink"
        gender = "Female"
    xy = latent_embedded[attr_arr==i]
    label = attr_arr[attr_arr==i]
    ax1.scatter(xy[:,0], xy[:,1], c=color, label=gender,
               alpha=0.3)
ax1.legend()
ax1.set_title("Gender")
attr_arr = np.array(test_attr["Wearing_Lipstick"])
for i in [0,1]:
    if i==1:
        color="hotpink"
        gender = "Lipstick"
    else:
        color="steelblue"
        gender = "No Lipstick"
    xy = latent_embedded[attr_arr==i]
    label = attr_arr[attr_arr==i]
    ax2.scatter(xy[:,0], xy[:,1], c=color, label=gender,
               alpha=0.3)
ax2.legend()
ax2.set_title("Wearing Lipstick")
plt.savefig("./VAE_output/fig1_5.jpg")
plt.show()
